# %%
#1. Librerías.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
#2. Constantes.
df_final_path = "./pruebas_batch/df_final_IL_1610_nuevasvariablesinternacionales_s1500.csv"

# %%
#3. Lectura.
df_final = pd.read_csv(df_final_path)

# %%
#4. Análisis estadísticos univariados básicos - Tabla.
df_final.describe()
# Out:
#        horizonte_dias       merval  volatilidad_merval    fx_usdars  \
# count      154.000000  1500.000000           1500.0000  1500.000000
# mean       110.733766    -0.024233              0.1356     0.099867
# std        599.527513     0.212676              0.2607     0.297690
# min          0.000000    -1.000000             -1.0000    -1.000000
# 25%          4.250000     0.000000              0.0000     0.000000
# 50%         15.000000     0.000000              0.0000     0.000000
# 75%         60.000000     0.000000              0.2000     0.000000
# max       7300.000000     0.800000              1.0000     1.000000
#
#         spread_usd    tasa_bcra  bonos_soberanos  spread_bonos  \
# count  1500.000000  1500.000000      1500.000000   1500.000000
# mean      0.096267    -0.011400        -0.016733      0.030533
# std       0.306913     0.162402         0.208884      0.218372
# min      -1.000000    -1.000000        -1.000000     -0.800000
# 25%       0.000000     0.000000         0.000000      0.000000
# 50%       0.000000     0.000000         0.000000      0.000000
# 75%       0.000000     0.000000         0.000000      0.000000
# max       1.000000     1.000000         0.900000      1.000000
#
#        actividad_economica  volumen_mercado  ...  impacto_sector_industrial  \
# count          1500.000000      1500.000000  ...                1500.000000
# mean             -0.014033         0.061333  ...                  -0.014267
# std               0.173594         0.151471  ...                   0.160666
# min              -1.000000        -0.500000  ...                  -1.000000
# 25%               0.000000         0.000000  ...                   0.000000
# 50%               0.000000         0.000000  ...                   0.000000
# 75%               0.000000         0.000000  ...                   0.000000
# max               0.800000         1.000000  ...                   1.000000
#
#        impacto_eeuu  impacto_brasil  impacto_mercosur  \
# count   1500.000000     1500.000000       1500.000000
# mean      -0.016967       -0.002867         -0.001933
# std        0.159637        0.064920          0.038522
# min       -1.000000       -0.500000         -0.500000
# 25%        0.000000        0.000000          0.000000
# 50%        0.000000        0.000000          0.000000
# 75%        0.000000        0.000000          0.000000
# max        1.000000        0.700000          0.400000
#
#        impacto_prestamos_internacionales  impacto_fmi  impacto_commodities  \
# count                        1500.000000  1500.000000          1500.000000
# mean                            0.036667     0.029600             0.015067
# std                             0.158679     0.164018             0.156171
# min                            -1.000000    -1.000000            -1.000000
# 25%                             0.000000     0.000000             0.000000
# 50%                             0.000000     0.000000             0.000000
# 75%                             0.000000     0.000000             0.000000
# max                             0.800000     0.800000             1.000000
#
#        impacto_bolsa_extranjera  score_fuente    confianza
# count               1500.000000   1500.000000  1500.000000
# mean                  -0.009600      0.657800     0.734767
# std                    0.110435      0.071479     0.235273
# min                   -1.000000      0.500000     0.200000
# 25%                    0.000000      0.600000     0.800000
# 50%                    0.000000      0.700000     0.800000
# 75%                    0.000000      0.700000     0.900000
# max                    0.600000      0.800000     0.900000
#
# [8 rows x 29 columns]

# %%
#5. Análisis estadísticos univariados básicos - Gráfico.
#a. Configuración general de gráficos.
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 5)

#b. Seleccion que columnas voy a graficar.
df_final = df_final.iloc[:,6:] 

#c. Función para analizar columnas automáticamente según tipo.
def analizar_columnas(df_final):
    for col in df_final.columns:
        print(f"\n{'='*40}\nColumna: {col}")
        print(df_final[col].describe(include='all'))

        if df_final[col].dtype == "object": 
            #i. Frecuencia de valores.
            counts = df_final[col].value_counts(dropna=False)
            print(counts)
            #ii. Gráfico de barras.
            #counts.plot(kind='bar')
            #plt.title(f"Frecuencia de '{col}'")
            #plt.ylabel("Conteo")
            #plt.show()
    
        elif df_final[col].dtype == "bool":
            #i. Frecuencia de valores.
            counts = df_final[col].value_counts(dropna=False)
            print(counts)
            #ii. Gráfico de barras.
            counts.plot(kind='bar')
            plt.title(f"Frecuencia de '{col}'")
            plt.ylabel("Conteo")
            plt.show()

        elif pd.api.types.is_numeric_dtype(df_final[col]):
            #iii. Estadísticas básicas.
            print(df_final[col].describe())
            #iv. Histograma.
            sns.histplot(df_final[col].dropna(), kde=True, bins=20)
            plt.title(f"Distribución de '{col}'")
            plt.xlabel(col)
            plt.show()

#c. Llamo a la función.
analizar_columnas(df_final)
# Out:
# ========================================
# Columna: tipo_actor_principal
# count                  1500
# unique                   11
# top       gobierno_nacional
# freq                    672
# Name: tipo_actor_principal, dtype: object
# tipo_actor_principal
# gobierno_nacional          672
# empresa_local              201
# desconocido                154
# bcra                       123
# empresa_extranjera          74
# organismo_internacional     62
# provincia                   55
# congreso                    47
# poder_judicial              44
# municipio                   38
# sindicato                   30
# Name: count, dtype: int64
#
# ========================================
# Columna: nombre_actor_principal
# count             1500
# unique             567
# top       Javier Milei
# freq               139
# Name: nombre_actor_principal, dtype: object
# nombre_actor_principal
# Javier Milei                                           139
# unknown                                                108
# Gobierno nacional                                       72
# Gobierno Nacional                                       51
# Banco Central (BCRA)                                    43
#                                                       ...
# Supermercados Coto                                       1
# Alfredo Silverio Gusmán                                  1
# Franuí                                                   1
# Estado argentino                                         1
# Instituto Nacional de Estadísticas y Censos (Indec)      1
# Name: count, Length: 567, dtype: int64
#
# ========================================
# Columna: empresas_mencionadas
# count     1500
# unique     611
# top         []
# freq       793
# Name: empresas_mencionadas, dtype: object
# empresas_mencionadas
# []                                                                                                                                                                               793
# ['Banco Nación']                                                                                                                                                                  15
# ['Bitso', 'Binance']                                                                                                                                                              11
# ['Lemon']                                                                                                                                                                          9
# ['Lemon', 'Binance', 'Tether', 'Coinbase', 'BBC']                                                                                                                                  8
#                                                                                                                                                                                 ...
# ['Banco Nación', 'BBVA', 'Banco de la Ciudad', 'Banco Santander', 'Banco Patagonia', 'Macro', 'Grupo SBS', 'Delphos Investment', 'Banco Supervielle', 'Cresud', 'Loma Negra']      1
# ['KIP Protocol', 'KIP Network Inc', 'Cardano', 'The New York Times', 'LA NACION']                                                                                                  1
# ['Cámara Argentina de la Construcción (CAMARCO)', 'Federación Argentina de Entidades de la Construcción (FAEC)']                                                                   1
# ['La Nación', 'Bloomberg', 'JP Morgan', 'Ripio', 'Banco Nación']                                                                                                                   1
# ['KIP Protocol', 'Tech Forum']                                                                                                                                                     1
# Name: count, Length: 611, dtype: int64
#
# ========================================
# Columna: tickers_mencionados
# count     1500
# unique      52
# top         []
# freq      1357
# Name: tickers_mencionados, dtype: object
# tickers_mencionados
# []                                                                                                                                                                                               1357
# ['LIBRA']                                                                                                                                                                                          38
# ['AL30']                                                                                                                                                                                           18
# ['BTC']                                                                                                                                                                                            11
# ['BTC', 'ETH', 'BNB', 'ADA', 'SOL', 'AVAX', 'LTC', 'LINK', 'NEAR', 'USDT', 'USDC']                                                                                                                  9
# ['AL30', 'AL30D', 'AL30C']                                                                                                                                                                          8
# ['AL30', 'GD30']                                                                                                                                                                                    7
# ['ETH']                                                                                                                                                                                             4
# ['ETH', 'BTC']                                                                                                                                                                                      3
# ['LIBRA', 'TRUMP']                                                                                                                                                                                  2
# ['TSLA']                                                                                                                                                                                            2
# ['BTC', 'ETH', 'SOL', 'TON', 'SHIB']                                                                                                                                                                1
# ['XRP', 'XLM', 'DOGE', 'ADA', 'LINK', 'AVAX', 'BTC', 'MANA', 'LTC', 'SOL', 'UNI', 'DOT', 'BCH', 'XAUT', 'ETH']                                                                                      1
# ['BUR']                                                                                                                                                                                             1
# ['AMX']                                                                                                                                                                                             1
# ['YPFD', 'TXR', 'CRES', 'GPRK']                                                                                                                                                                     1
# ['BTC', 'ETH', 'DAI']                                                                                                                                                                               1
# ['BTC', 'ETH', 'XRP', 'SOL']                                                                                                                                                                        1
# ['BYMA']                                                                                                                                                                                            1
# ['LIBRA', 'SOL', 'USDC', 'BRYAN']                                                                                                                                                                   1
# ['YPF']                                                                                                                                                                                             1
# ['GD35', 'GD41']                                                                                                                                                                                    1
# ['LIBRA', 'HAWK']                                                                                                                                                                                   1
# ['EWZ']                                                                                                                                                                                             1
# ['BTC', 'ETH', 'LTC', 'LINK', 'TRX', 'LCAI']                                                                                                                                                        1
# ['LECAP S31M5', 'LECAP S30J5', 'BONCER']                                                                                                                                                            1
# ['LIBRA', 'SOL', 'USDC']                                                                                                                                                                            1
# ['BTC', 'ETH', 'WBTC', 'AAVE', 'LINK', 'TRX', 'ENA', 'TRUMP', 'MELANIA', 'SOL', 'XRP']                                                                                                              1
# ['BTC', 'ETH', 'XRP', 'BNB', 'SOL', 'DOGE', 'ADA', 'SUI', 'MTPLF']                                                                                                                                  1
# ['BTC', 'ETH', 'DOGE', 'HBAR', 'LINK', 'TRUMP', 'MELANIA']                                                                                                                                          1
# ['TGT', 'WFC', 'V', 'F', 'JNJ', 'PSX', 'PFE', 'IBM', 'XOM', 'CVX', 'LLY', 'MMM', 'MSFT', 'DOW', 'MCD', 'GOOGL', 'GOLD', 'UNH', 'EA', 'GM', 'META', 'HD', 'QCOM', 'NEM', 'LMT', 'BA.C', 'PEP']       1
# ['MELI']                                                                                                                                                                                            1
# ['LIBRA', 'BITCOIN']                                                                                                                                                                                1
# ['BTC', 'ETH', 'TRX', 'LINK', 'AVAX', 'XRP', 'SOL', 'DOGE', 'ADA']                                                                                                                                  1
# ['AL30D', 'GD38D', 'AL30', 'GD30']                                                                                                                                                                  1
# ['LIBRA', 'GD35', 'BOPREAL27']                                                                                                                                                                      1
# ['TSLA', 'AMZN']                                                                                                                                                                                    1
# ['AL35D', 'GD46D', 'AL30', 'GD30', 'BTC', 'ETH', 'DAI']                                                                                                                                             1
# ['AL29D', 'GD29D', 'BYMA', 'EMB']                                                                                                                                                                   1
# ['AL30', 'GD30', 'BTC', 'ETH', 'DAI']                                                                                                                                                               1
# ['LIBRA', 'MELANIA', 'TRUMP']                                                                                                                                                                       1
# ['AL30C', 'AL30D', 'AL41D', 'GD35D']                                                                                                                                                                1
# ['ETH', 'BTC', 'SOL']                                                                                                                                                                               1
# ['GD46', 'GD35', 'AL41', 'GD30']                                                                                                                                                                    1
# ['BTC', 'ETH', 'BNB', 'ADA', 'SOL', 'AVAX', 'LTC', 'LINK', 'NEAR']                                                                                                                                  1
# ['GD2035']                                                                                                                                                                                          1
# ['LIBRA', 'LIBA']                                                                                                                                                                                   1
# ['GD38', 'GD41', 'GD46', 'GD35']                                                                                                                                                                    1
# ['BTC', 'MIND', 'NEAR', 'FET', 'AGIX', 'OCEAN', 'TAO']                                                                                                                                              1
# ['BTC', 'ETH', 'BNB', 'ADA', 'SOL', 'AVAX', 'LINK', 'NEAR', 'USDT', 'USDC']                                                                                                                         1
# ['S31L5', 'S31O5', 'TZXM7', 'T30J6', 'S17E5', 'CUAP', 'DICP']                                                                                                                                       1
# ['BLK', 'BK', 'JPM', 'C']                                                                                                                                                                           1
# Name: count, dtype: int64
#
# ========================================
# Columna: sectores_mencionados
# count     1500
# unique    1360
# top         []
# freq        55
# Name: sectores_mencionados, dtype: object
# sectores_mencionados
# []                                                                                                                55
# ['política', 'electoral']                                                                                         11
# ['política']                                                                                                      10
# ['criptomonedas', 'fintech', 'tecnología']                                                                         9
# ['bancario', 'financiero']                                                                                         6
#                                                                                                                   ..
# ['sector financiero', 'banca', 'mercado cambiario']                                                                1
# ['financiero', 'cambiario', 'banco_central']                                                                       1
# ['finanzas', 'mercado de capitales', 'sector público', 'instituciones financieras']                                1
# ['tributario', 'recaudación', 'seguridad_social', 'agroexportador', 'comercio_internacional', 'importaciones']     1
# ['gobierno provincial', 'intendentes', 'legislatura', 'partidos políticos']                                        1
# Name: count, Length: 1360, dtype: int64
#
# ========================================
# Columna: tipo_evento
# count          1500
# unique           10
# top       monetario
# freq            314
# Name: tipo_evento, dtype: object
# tipo_evento
# monetario          314
# externo            238
# desconocido        238
# regulatorio        179
# fiscal             160
# corporativo        126
# otro               108
# sindical_social     64
# judicial            44
# electoral           29
# Name: count, dtype: int64
#
# ========================================
# Columna: shock
# count         1500
# unique           5
# top       negativo
# freq           394
# Name: shock, dtype: object
# shock
# negativo       394
# mixto          343
# neutro         279
# positivo       251
# desconocido    233
# Name: count, dtype: int64
#
# ========================================
# Columna: caracter
# count        1500
# unique          4
# top       vigente
# freq          902
# Name: caracter, dtype: object
# caracter
# vigente        902
# prospectivo    329
# desconocido    174
# retroactivo     95
# Name: count, dtype: int64
#
# ========================================
# Columna: horizonte_dias
# count     154.000000
# mean      110.733766
# std       599.527513
# min         0.000000
# 25%         4.250000
# 50%        15.000000
# 75%        60.000000
# max      7300.000000
# Name: horizonte_dias, dtype: float64
# count     154.000000
# mean      110.733766
# std       599.527513
# min         0.000000
# 25%         4.250000
# 50%        15.000000
# 75%        60.000000
# max      7300.000000
# Name: horizonte_dias, dtype: float64
# ========================================
# Columna: merval
# count    1500.000000
# mean       -0.024233
# std         0.212676
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: merval, dtype: float64
# count    1500.000000
# mean       -0.024233
# std         0.212676
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: merval, dtype: float64
# ========================================
# Columna: volatilidad_merval
# count    1500.0000
# mean        0.1356
# std         0.2607
# min        -1.0000
# 25%         0.0000
# 50%         0.0000
# 75%         0.2000
# max         1.0000
# Name: volatilidad_merval, dtype: float64
# count    1500.0000
# mean        0.1356
# std         0.2607
# min        -1.0000
# 25%         0.0000
# 50%         0.0000
# 75%         0.2000
# max         1.0000
# Name: volatilidad_merval, dtype: float64
# ========================================
# Columna: fx_usdars
# count    1500.000000
# mean        0.099867
# std         0.297690
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: fx_usdars, dtype: float64
# count    1500.000000
# mean        0.099867
# std         0.297690
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: fx_usdars, dtype: float64
# ========================================
# Columna: spread_usd
# count    1500.000000
# mean        0.096267
# std         0.306913
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: spread_usd, dtype: float64
# count    1500.000000
# mean        0.096267
# std         0.306913
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: spread_usd, dtype: float64
# ========================================
# Columna: tasa_bcra
# count    1500.000000
# mean       -0.011400
# std         0.162402
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: tasa_bcra, dtype: float64
# count    1500.000000
# mean       -0.011400
# std         0.162402
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: tasa_bcra, dtype: float64
# ========================================
# Columna: bonos_soberanos
# count    1500.000000
# mean       -0.016733
# std         0.208884
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.900000
# Name: bonos_soberanos, dtype: float64
# count    1500.000000
# mean       -0.016733
# std         0.208884
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.900000
# Name: bonos_soberanos, dtype: float64
# ========================================
# Columna: spread_bonos
# count    1500.000000
# mean        0.030533
# std         0.218372
# min        -0.800000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: spread_bonos, dtype: float64
# count    1500.000000
# mean        0.030533
# std         0.218372
# min        -0.800000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: spread_bonos, dtype: float64
# ========================================
# Columna: actividad_economica
# count    1500.000000
# mean       -0.014033
# std         0.173594
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: actividad_economica, dtype: float64
# count    1500.000000
# mean       -0.014033
# std         0.173594
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: actividad_economica, dtype: float64
# ========================================
# Columna: volumen_mercado
# count    1500.000000
# mean        0.061333
# std         0.151471
# min        -0.500000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: volumen_mercado, dtype: float64
# count    1500.000000
# mean        0.061333
# std         0.151471
# min        -0.500000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: volumen_mercado, dtype: float64
# ========================================
# Columna: valencia_general
# count    1500.000000
# mean       -0.058033
# std         0.349297
# min        -1.000000
# 25%        -0.300000
# 50%         0.000000
# 75%         0.100000
# max         1.000000
# Name: valencia_general, dtype: float64
# count    1500.000000
# mean       -0.058033
# std         0.349297
# min        -1.000000
# 25%        -0.300000
# 50%         0.000000
# 75%         0.100000
# max         1.000000
# Name: valencia_general, dtype: float64
# ========================================
# Columna: gobernanza
# count    1500.000000
# mean       -0.077667
# std         0.276572
# min        -1.000000
# 25%        -0.200000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: gobernanza, dtype: float64
# count    1500.000000
# mean       -0.077667
# std         0.276572
# min        -1.000000
# 25%        -0.200000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: gobernanza, dtype: float64
# ========================================
# Columna: expectativa_macro_corto
# count    1500.000000
# mean       -0.072067
# std         0.222739
# min        -1.000000
# 25%        -0.200000
# 50%         0.000000
# 75%         0.000000
# max         0.600000
# Name: expectativa_macro_corto, dtype: float64
# count    1500.000000
# mean       -0.072067
# std         0.222739
# min        -1.000000
# 25%        -0.200000
# 50%         0.000000
# 75%         0.000000
# max         0.600000
# Name: expectativa_macro_corto, dtype: float64
# ========================================
# Columna: expectativa_macro_largo
# count    1500.000000
# mean       -0.011133
# std         0.185209
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.700000
# Name: expectativa_macro_largo, dtype: float64
# count    1500.000000
# mean       -0.011133
# std         0.185209
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.700000
# Name: expectativa_macro_largo, dtype: float64
# ========================================
# Columna: expectativa_fin_corto
# count    1500.000000
# mean       -0.062533
# std         0.227642
# min        -1.000000
# 25%        -0.100000
# 50%         0.000000
# 75%         0.000000
# max         0.600000
# Name: expectativa_fin_corto, dtype: float64
# count    1500.000000
# mean       -0.062533
# std         0.227642
# min        -1.000000
# 25%        -0.100000
# 50%         0.000000
# 75%         0.000000
# max         0.600000
# Name: expectativa_fin_corto, dtype: float64
# ========================================
# Columna: expectativa_fin_largo
# count    1500.000000
# mean       -0.006600
# std         0.173676
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.700000
# Name: expectativa_fin_largo, dtype: float64
# count    1500.000000
# mean       -0.006600
# std         0.173676
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.700000
# Name: expectativa_fin_largo, dtype: float64
# ========================================
# Columna: menciona_inflacion
# count      1500
# unique        2
# top       False
# freq       1047
# Name: menciona_inflacion, dtype: object
# menciona_inflacion
# False    1047
# True      453
# Name: count, dtype: int64
# ========================================
# Columna: menciona_pbi
# count      1500
# unique        2
# top       False
# freq       1352
# Name: menciona_pbi, dtype: object
# menciona_pbi
# False    1352
# True      148
# Name: count, dtype: int64
# ========================================
# Columna: menciona_reservas
# count      1500
# unique        2
# top       False
# freq       1335
# Name: menciona_reservas, dtype: object
# menciona_reservas
# False    1335
# True      165
# Name: count, dtype: int64
# ========================================
# Columna: menciona_embi
# count      1500
# unique        2
# top       False
# freq       1413
# Name: menciona_embi, dtype: object
# menciona_embi
# False    1413
# True       87
# Name: count, dtype: int64
# ========================================
# Columna: menciona_deuda
# count      1500
# unique        2
# top       False
# freq       1190
# Name: menciona_deuda, dtype: object
# menciona_deuda
# False    1190
# True      310
# Name: count, dtype: int64
# ========================================
# Columna: menciona_fmi
# count      1500
# unique        2
# top       False
# freq       1251
# Name: menciona_fmi, dtype: object
# menciona_fmi
# False    1251
# True      249
# Name: count, dtype: int64
# ========================================
# Columna: menciona_salarios_paritarias
# count      1500
# unique        2
# top       False
# freq       1354
# Name: menciona_salarios_paritarias, dtype: object
# menciona_salarios_paritarias
# False    1354
# True      146
# Name: count, dtype: int64
# ========================================
# Columna: menciona_tipo_cambio
# count      1500
# unique        2
# top       False
# freq        802
# Name: menciona_tipo_cambio, dtype: object
# menciona_tipo_cambio
# False    802
# True     698
# Name: count, dtype: int64
# ========================================
# Columna: menciona_confianza_consumidor
# count      1500
# unique        2
# top       False
# freq       1477
# Name: menciona_confianza_consumidor, dtype: object
# menciona_confianza_consumidor
# False    1477
# True       23
# Name: count, dtype: int64
# ========================================
# Columna: menciona_sector_bancario
# count      1500
# unique        2
# top       False
# freq       1069
# Name: menciona_sector_bancario, dtype: object
# menciona_sector_bancario
# False    1069
# True      431
# Name: count, dtype: int64
# ========================================
# Columna: impacto_sector_bancario
# count    1500.000000
# mean        0.009000
# std         0.156147
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_sector_bancario, dtype: float64
# count    1500.000000
# mean        0.009000
# std         0.156147
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_sector_bancario, dtype: float64
# ========================================
# Columna: menciona_sector_energia
# count      1500
# unique        2
# top       False
# freq       1275
# Name: menciona_sector_energia, dtype: object
# menciona_sector_energia
# False    1275
# True      225
# Name: count, dtype: int64
# ========================================
# Columna: impacto_sector_energia
# count    1500.00000
# mean        0.01840
# std         0.16256
# min        -1.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max         1.00000
# Name: impacto_sector_energia, dtype: float64
# count    1500.00000
# mean        0.01840
# std         0.16256
# min        -1.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max         1.00000
# Name: impacto_sector_energia, dtype: float64
# ========================================
# Columna: menciona_sector_agroexportador
# count      1500
# unique        2
# top       False
# freq       1225
# Name: menciona_sector_agroexportador, dtype: object
# menciona_sector_agroexportador
# False    1225
# True      275
# Name: count, dtype: int64
# ========================================
# Columna: impacto_sector_agroexportador
# count    1500.000000
# mean        0.018733
# std         0.217180
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_sector_agroexportador, dtype: float64
# count    1500.000000
# mean        0.018733
# std         0.217180
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_sector_agroexportador, dtype: float64
# ========================================
# Columna: menciona_sector_industrial
# count      1500
# unique        2
# top       False
# freq       1225
# Name: menciona_sector_industrial, dtype: object
# menciona_sector_industrial
# False    1225
# True      275
# Name: count, dtype: int64
# ========================================
# Columna: impacto_sector_industrial
# count    1500.000000
# mean       -0.014267
# std         0.160666
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_sector_industrial, dtype: float64
# count    1500.000000
# mean       -0.014267
# std         0.160666
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_sector_industrial, dtype: float64
# ========================================
# Columna: menciona_eeuu
# count      1500
# unique        2
# top       False
# freq       1106
# Name: menciona_eeuu, dtype: object
# menciona_eeuu
# False    1106
# True      394
# Name: count, dtype: int64
# ========================================
# Columna: impacto_eeuu
# count    1500.000000
# mean       -0.016967
# std         0.159637
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_eeuu, dtype: float64
# count    1500.000000
# mean       -0.016967
# std         0.159637
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_eeuu, dtype: float64
# ========================================
# Columna: menciona_brasil
# count      1500
# unique        2
# top       False
# freq       1349
# Name: menciona_brasil, dtype: object
# menciona_brasil
# False    1349
# True      151
# Name: count, dtype: int64
# ========================================
# Columna: impacto_brasil
# count    1500.000000
# mean       -0.002867
# std         0.064920
# min        -0.500000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.700000
# Name: impacto_brasil, dtype: float64
# count    1500.000000
# mean       -0.002867
# std         0.064920
# min        -0.500000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.700000
# Name: impacto_brasil, dtype: float64
# ========================================
# Columna: menciona_mercosur
# count      1500
# unique        2
# top       False
# freq       1475
# Name: menciona_mercosur, dtype: object
# menciona_mercosur
# False    1475
# True       25
# Name: count, dtype: int64
# ========================================
# Columna: impacto_mercosur
# count    1500.000000
# mean       -0.001933
# std         0.038522
# min        -0.500000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.400000
# Name: impacto_mercosur, dtype: float64
# count    1500.000000
# mean       -0.001933
# std         0.038522
# min        -0.500000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.400000
# Name: impacto_mercosur, dtype: float64
# ========================================
# Columna: menciona_prestamos_internacionales
# count      1500
# unique        2
# top       False
# freq       1256
# Name: menciona_prestamos_internacionales, dtype: object
# menciona_prestamos_internacionales
# False    1256
# True      244
# Name: count, dtype: int64
# ========================================
# Columna: impacto_prestamos_internacionales
# count    1500.000000
# mean        0.036667
# std         0.158679
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: impacto_prestamos_internacionales, dtype: float64
# count    1500.000000
# mean        0.036667
# std         0.158679
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: impacto_prestamos_internacionales, dtype: float64
# ========================================
# Columna: impacto_fmi
# count    1500.000000
# mean        0.029600
# std         0.164018
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: impacto_fmi, dtype: float64
# count    1500.000000
# mean        0.029600
# std         0.164018
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.800000
# Name: impacto_fmi, dtype: float64
# ========================================
# Columna: menciona_commodities
# count      1500
# unique        2
# top       False
# freq       1283
# Name: menciona_commodities, dtype: object
# menciona_commodities
# False    1283
# True      217
# Name: count, dtype: int64
# ========================================
# Columna: impacto_commodities
# count    1500.000000
# mean        0.015067
# std         0.156171
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_commodities, dtype: float64
# count    1500.000000
# mean        0.015067
# std         0.156171
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: impacto_commodities, dtype: float64
# ========================================
# Columna: menciona_bolsa_extranjera
# count      1500
# unique        2
# top       False
# freq       1360
# Name: menciona_bolsa_extranjera, dtype: object
# menciona_bolsa_extranjera
# False    1360
# True      140
# Name: count, dtype: int64
# ========================================
# Columna: impacto_bolsa_extranjera
# count    1500.000000
# mean       -0.009600
# std         0.110435
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.600000
# Name: impacto_bolsa_extranjera, dtype: float64
# count    1500.000000
# mean       -0.009600
# std         0.110435
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.600000
# Name: impacto_bolsa_extranjera, dtype: float64
# ========================================
# Columna: categoria_fuente
# count             1500
# unique               2
# top       periodistica
# freq              1498
# Name: categoria_fuente, dtype: object
# categoria_fuente
# periodistica    1498
# analisis           2
# Name: count, dtype: int64
#
# ========================================
# Columna: score_fuente
# count    1500.000000
# mean        0.657800
# std         0.071479
# min         0.500000
# 25%         0.600000
# 50%         0.700000
# 75%         0.700000
# max         0.800000
# Name: score_fuente, dtype: float64
# count    1500.000000
# mean        0.657800
# std         0.071479
# min         0.500000
# 25%         0.600000
# 50%         0.700000
# 75%         0.700000
# max         0.800000
# Name: score_fuente, dtype: float64
# ========================================
# Columna: confianza
# count    1500.000000
# mean        0.734767
# std         0.235273
# min         0.200000
# 25%         0.800000
# 50%         0.800000
# 75%         0.900000
# max         0.900000
# Name: confianza, dtype: float64
# count    1500.000000
# mean        0.734767
# std         0.235273
# min         0.200000
# 25%         0.800000
# 50%         0.800000
# 75%         0.900000
# max         0.900000
# Name: confianza, dtype: float64
# ========================================
# Columna: empresas_mencionadas_list
# count      1
# unique     1
# top       []
# freq       1
# Name: empresas_mencionadas_list, dtype: object
# empresas_mencionadas_list
# NaN    1499
# []        1
# Name: count, dtype: int64
#
# ========================================
# Columna: personas_mencionadas
# count                                                     1
# unique                                                    1
# top       ['Diego Valenzuela', 'Javier Milei', 'Karina M...
# freq                                                      1
# Name: personas_mencionadas, dtype: object
# personas_mencionadas
# NaN                                                                                                                                                                                                                                                                                               1499
# ['Diego Valenzuela', 'Javier Milei', 'Karina Milei', 'Patricia Bullrich', 'Mauricio Macri', 'Daniela Reich', 'Sebastián Pareja', 'Ramiro Egüen', 'Horacio Rodríguez Larreta', 'Santiago Caputo', 'Axel Kicillof', 'José Luis Espert', 'Jorge Macri', 'Francisco De Narváez', 'Diego Santilli']       1
# Name: count, dtype: int64

# %%
#6. Posible Data Engineering posterior.
#- Borrar fx_us porque solo trae dos valores (no aporta información relevante).
#- Conteo de palabras de la noticia (información de su importancia?)
#- Conteo de empresas implicadas.
#- Conteo de tickers mencionados.
